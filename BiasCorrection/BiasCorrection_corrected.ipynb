# %%
import datetime
from datetime import date
import seaborn as sns

import copy

#from datetime import date_range
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn import metrics  

import os
import os.path

#pd.set_option('display.height', 1000)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

plt.close("all")

def plotFigure(data_plot,file_name,order):
    fig = plt.figure(order, figsize=(9, 6))
    ax = fig.add_subplot(111)
    bp = ax.boxplot(data_plot)
    fig.savefig(file_name, bbox_inches='tight')
    plt.close()
    
proj_dir   = '/Users/robertshahn/Documents/python-projects/wx_aval_repo/BiasCorrection'

data_file = os.path.join(proj_dir,'BiasCorrectionData_new.csv')

date_rng = pd.date_range(start='12/11/2018', end='4/30/2019', freq='D')
#date_rng = pd.date_range(start='11/25/2018', end='5/13/2019', freq='D')



df = pd.read_csv(data_file)
df.columns = df.columns.str.strip() 
pd.options.display.float_format = '{:,.2f}'.format
#df.drop(['Unnamed: 0'], axis=1, inplace=True)
df = df.iloc[16:157,:]
#df['WRF Day'].shape

#df.truncate(after=112)
df['Date'] = date_rng
df = df.set_index('Date')

#correction_factor = [(tau - 1)/tau]*yesterdays_factor + (1/tau)*(most_recent_fcst_pcp/most_recent_obs_pcp)

columns = ['HUR2','MTB2','WAP2','STV2','SNO2','LVN2','MIS2','CMT2','PAR2','WHP2','TML2','MHM2', \
          'HUR3','MTB3','WAP3','STV3','SNO3','LVN3','MIS3','CMT3','PAR3','WHP3','TML3','MHM3']
#correction_factor = [(tau - 1)/tau]*yesterdays_factor + (1/tau)*(most_recent_fcst_pcp/most_recent_obs_pcp)
names = ['HUR','MTB','WAP','STV','SNO','LVN','MIS','CMT','PAR','WHP','TML','MHM']
df.drop(columns, inplace=True, axis=1)
#names = ['STV']
for name in names:
    tau = 30
    #cf.iloc[0] = 1
    #print(cf.head())
#    unchanged = True
    df2 = copy.deepcopy(df.filter(regex=name))
    df2[name+'_CF'] = 0
    df2[name+'_BC'] = 0
    bc_fcst = df2[name+'_BC']
    df2[name+'_Raw_Bias'] = 0
    raw_bias = df2[name+'_Raw_Bias']
    df2[name+'_BC_Bias'] = 0
    bc_bias = df2[name+'_BC_Bias']
    obs = df2[name+'1']
    fcst = df2[name+'4']
    cf = df2[name+'_CF']
    cf.iloc[0] = 1
    df3 = copy.deepcopy(df.filter(regex=name).dropna(axis=0, how='any'))
    df3[name+'_CF'] = 0
    cf_drop = df3[name+'_CF']
    df3[name+'_BC'] = 0
    bc_fcst_drop = df3[name+'_BC']
    df3[name+'_Raw_Bias'] = 0
    raw_bias_drop = df3[name+'_Raw_Bias']
    df3[name+'_BC_Bias'] = 0
    bc_bias_drop = df3[name+'_BC_Bias']
    obs_drop = df2[name+'1']
    fcst_drop = df2[name+'4']
    cf_drop = df2[name+'_CF']
    cf.iloc[0] = 1
    for i in range(len(df2)-1):
        if (obs.iloc[i]<=0.01  or np.isnan(obs.iloc[i])==True or np.isnan(fcst.iloc[i])==True):
    #        print("i = " + str(i))
            cf.iloc[i+1] = cf.iloc[i]
#             print("cf IS " + str(cf.iloc[i]))
#             print("cf+1 IS = " + str(cf.iloc[i+1]))
        else:
    #        unchanged = False
    #       print("j = " + str(i))
    #         print(round(fcst.iloc[i],3))
    #        cf.iloc[i+1] = ((tau - 1)/tau)*cf.iloc[i] + (1/tau)*(fcst.iloc[i]/obs.iloc[i])
            cf.iloc[i+1] = ((tau - 1)/tau)*cf.iloc[i] + (1/tau)*(fcst.iloc[i]/obs.iloc[i])
            #code to avoid large jumps in cf
            if(abs((cf.iloc[i+1]/cf.iloc[i]))>1.5 and (fcst.iloc[i]+obs.iloc[i])<1):
                cf.iloc[i+1] = cf.iloc[i]+(cf.iloc[i+1]-cf.iloc[i])/(cf.iloc[i+1]+cf.iloc[i])
        bc_fcst.iloc[i] = fcst.iloc[i]/cf.iloc[i]
        bc_bias.iloc[i] = bc_fcst.iloc[i] - obs.iloc[i]
        raw_bias.iloc[i] = fcst.iloc[i] - obs.iloc[i]
#         print("date is " + str(df.index.date[i]) + "; fcst is " + str(round(fcst.iloc[i],2)) + "; obs is " + str(round(obs.iloc[i],2)) + "; cf is " + str(round(cf.iloc[i],2)) + \
#                 "; fcst_bc is " + str(round(bc_fcst.iloc[i],2)))
        print("date is " + str(df.index.date[i]) + "; fcst is " + str(round(fcst.iloc[i],2)) + "; obs is " + str(round(obs.iloc[i],2)) + "; cf is " + str(round(cf.iloc[i],2)) + \
                "; bc_fcst is " + str(round(bc_fcst.iloc[i],2)))
        import copy
#       df2 = copy.deepcopy(df.filter(regex=name))
        a = open(proj_dir+'/'+name+'_precip.txt', 'w')
        a.write(str(df3))
        a.close()         

    fig = plt.figure(figsize=(16,16))
    raw_bias.plot(figsize=(20,10), fontsize=20, color="green")
    bc_bias.plot(figsize=(20,10), fontsize=20, color="red")
#     bc_fcst.plot(figsize=(20,10), fontsize=20, color="blue")
#     fcst.plot(figsize=(20,10), fontsize=20, color="magenta")
#     obs.plot(figsize=(20,10), fontsize=20, color="orange")
    cf.plot(figsize=(20,10), fontsize=20, color="black")
    plt.xlabel('Month', fontsize=20)
    plt.ylabel('Precip Bias (")', fontsize=20)
    plt.figtext(0.35, 0.85,name+" Raw 1.33-km WRF MAE = " + str(round(metrics.mean_absolute_error(df2[name+'4'],df2[name+'1']),3)), wrap=True,
                horizontalalignment='center', fontsize=16)
    plt.figtext(0.35, 0.8,name+" Raw 1.33-km WRF MSE = " + str(round(metrics.mean_squared_error(df2[name+'4'],df2[name+'1']),3)), wrap=True,
                horizontalalignment='center', fontsize=16)
    plt.figtext(0.35, 0.75,name+" Raw 1.33-km WRF RMSE = " + str(round(np.sqrt(metrics.mean_absolute_error(df2[name+'4'],df2[name+'1'])),3)), 
                wrap=True, horizontalalignment='center', fontsize=16)
    plt.figtext(0.65, 0.85,name+" BC 1.33-km WRF MAE = " + str(round(metrics.mean_absolute_error(df2[name+'_BC'],df2[name+'1']),3)), wrap=True,
                horizontalalignment='center', fontsize=16)
    plt.figtext(0.35, 0.15,name+" Mean Raw 1.33-km WRF Bias = " + str(round(raw_bias.loc['2018-12-25 00:00:00':'2019-05-13 00:00:00'].mean(),3)), wrap=True,
                horizontalalignment='center', fontsize=16)
    plt.figtext(0.65, 0.8,name+" BC 1.33-km WRF MSE = " + str(round(metrics.mean_squared_error(df2[name+'_BC'],df2[name+'1']),3)), wrap=True,
                horizontalalignment='center', fontsize=16)
    plt.figtext(0.65, 0.75,name+" BC 1.33-km WRF RMSE = " + str(round(np.sqrt(metrics.mean_absolute_error(df2[name+'_BC'],df2[name+'1'])),3)), 
                wrap=True, horizontalalignment='center', fontsize=16)
    plt.figtext(0.65, 0.15,name+" Mean BC WRF 1.33-km Bias = " + str(round(bc_bias.loc['2018-12-25 00:00:00':'2019-05-13 00:00:00'].mean(), 3)), wrap=True,
                horizontalalignment='center', fontsize=16)

    plt.legend(fontsize=16)
    plt.title("STN = " + name + " FH12-36 Forecast Comparison: 1.33-km WRF and BC WRF Precip Bias", fontsize=20)
    plt.show()
    fig.savefig(proj_dir+'/STN='+name+'_WRF_vs_BCWRF.png',dpi=180)
    plt.close()
# Out:
# /Users/robertshahn/anaconda3/envs/wrf-proj/lib/python3.6/site-packages/pandas/core/indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# date is 2018-12-11; fcst is 0.36; obs is 0.16; cf is 1.0; bc_fcst is 0.36
# date is 2018-12-12; fcst is 1.07; obs is 1.25; cf is 1.04; bc_fcst is 1.03
# date is 2018-12-13; fcst is 0.52; obs is 0.92; cf is 1.04; bc_fcst is 0.5
# date is 2018-12-14; fcst is 0.32; obs is 0.58; cf is 1.02; bc_fcst is 0.31
# date is 2018-12-15; fcst is 0.75; obs is 0.5; cf is 1.0; bc_fcst is 0.75
# date is 2018-12-16; fcst is 0.22; obs is 0.27; cf is 1.02; bc_fcst is 0.22
# date is 2018-12-17; fcst is 0.43; obs is 1.03; cf is 1.01; bc_fcst is 0.42
# date is 2018-12-18; fcst is 0.46; obs is 1.03; cf is 0.99; bc_fcst is 0.46
# date is 2018-12-19; fcst is 0.41; obs is 1.06; cf is 0.98; bc_fcst is 0.42
# date is 2018-12-20; fcst is 0.18; obs is 0.63; cf is 0.96; bc_fcst is 0.19
# date is 2018-12-21; fcst is 1.55; obs is 1.15; cf is 0.93; bc_fcst is 1.66
# date is 2018-12-22; fcst is 0.24; obs is 0.04; cf is 0.95; bc_fcst is 0.25
# date is 2018-12-23; fcst is 0.58; obs is 0.64; cf is 1.12; bc_fcst is 0.52
# date is 2018-12-24; fcst is 0.05; obs is 1.08; cf is 1.11; bc_fcst is 0.05
# date is 2018-12-25; fcst is 0.07; obs is 0.0; cf is 1.07; bc_fcst is 0.07
# date is 2018-12-26; fcst is 0.02; obs is 0.0; cf is 1.07; bc_fcst is 0.02
# date is 2018-12-27; fcst is 0.32; obs is 0.16; cf is 1.07; bc_fcst is 0.3
# date is 2018-12-28; fcst is 0.02; obs is 0.11; cf is 1.1; bc_fcst is 0.02
# date is 2018-12-29; fcst is 0.49; obs is 0.38; cf is 1.07; bc_fcst is 0.46
# date is 2018-12-30; fcst is 0.57; obs is 0.75; cf is 1.08; bc_fcst is 0.53
# date is 2018-12-31; fcst is 0.0; obs is 0.06; cf is 1.07; bc_fcst is 0.0
# date is 2019-01-01; fcst is 0.0; obs is 0.0; cf is 1.03; bc_fcst is 0.0
# date is 2019-01-02; fcst is 0.0; obs is 0.0; cf is 1.03; bc_fcst is 0.0
# date is 2019-01-03; fcst is 0.29; obs is 0.6; cf is 1.03; bc_fcst is 0.28
# date is 2019-01-04; fcst is 1.15; obs is 1.51; cf is 1.02; bc_fcst is 1.13
# date is 2019-01-05; fcst is 0.06; obs is 0.5; cf is 1.01; bc_fcst is 0.06
# date is 2019-01-06; fcst is 0.47; obs is 0.35; cf is 0.98; bc_fcst is 0.48
# date is 2019-01-07; fcst is 0.95; obs is 0.57; cf is 0.99; bc_fcst is 0.96
# date is 2019-01-08; fcst is 0.23; obs is 0.14; cf is 1.01; bc_fcst is 0.23
# date is 2019-01-09; fcst is 0.17; obs is 0.42; cf is 1.03; bc_fcst is 0.16
# date is 2019-01-10; fcst is 0.38; obs is 0.9; cf is 1.01; bc_fcst is 0.38
# date is 2019-01-11; fcst is 0.02; obs is 0.1; cf is 0.99; bc_fcst is 0.02
# date is 2019-01-12; fcst is 0.0; obs is 0.0; cf is 0.97; bc_fcst is 0.0
# date is 2019-01-13; fcst is 0.0; obs is 0.0; cf is 0.97; bc_fcst is 0.0
# date is 2019-01-14; fcst is 0.0; obs is 0.0; cf is 0.97; bc_fcst is 0.0
# date is 2019-01-15; fcst is 0.0; obs is 0.0; cf is 0.97; bc_fcst is 0.0
# date is 2019-01-16; fcst is 0.0; obs is 0.0; cf is 0.97; bc_fcst is 0.0
# date is 2019-01-17; fcst is 0.0; obs is 0.02; cf is 0.97; bc_fcst is 0.0
# date is 2019-01-18; fcst is 0.14; obs is 0.62; cf is 0.93; bc_fcst is 0.15
# date is 2019-01-19; fcst is 0.53; obs is 0.74; cf is 0.91; bc_fcst is 0.58
# date is 2019-01-20; fcst is 0.06; obs is 0.32; cf is 0.9; bc_fcst is 0.07
# date is 2019-01-21; fcst is 0.0; obs is 0.0; cf is 0.88; bc_fcst is 0.0
# date is 2019-01-22; fcst is 0.01; obs is 0.0; cf is 0.88; bc_fcst is 0.01
# date is 2019-01-23; fcst is 0.31; obs is 0.43; cf is 0.88; bc_fcst is 0.35
# date is 2019-01-24; fcst is 0.01; obs is 0.08; cf is 0.88; bc_fcst is 0.01
# date is 2019-01-25; fcst is 0.0; obs is 0.0; cf is 0.85; bc_fcst is 0.0
# date is 2019-01-26; fcst is 0.0; obs is 0.0; cf is 0.85; bc_fcst is 0.0
# date is 2019-01-27; fcst is 0.0; obs is 0.0; cf is 0.85; bc_fcst is 0.0
# date is 2019-01-28; fcst is 0.0; obs is 0.0; cf is 0.85; bc_fcst is 0.0
# date is 2019-01-29; fcst is 0.0; obs is 0.0; cf is 0.85; bc_fcst is 0.0
# date is 2019-01-30; fcst is 0.0; obs is 0.0; cf is 0.85; bc_fcst is 0.0
# date is 2019-01-31; fcst is 0.0; obs is 0.0; cf is 0.85; bc_fcst is 0.0
# date is 2019-02-01; fcst is 0.05; obs is 0.17; cf is 0.85; bc_fcst is 0.06
# date is 2019-02-02; fcst is 0.14; obs is 0.35; cf is 0.83; bc_fcst is 0.17
# date is 2019-02-03; fcst is 0.0; obs is 0.01; cf is 0.82; bc_fcst is 0.0
# date is 2019-02-04; fcst is 0.06; obs is 0.03; cf is 0.82; bc_fcst is 0.07
# date is 2019-02-05; fcst is 0.09; obs is 0.01; cf is 0.86; bc_fcst is 0.11
# date is 2019-02-06; fcst is 0.0; obs is 0.0; cf is 0.86; bc_fcst is 0.0
# date is 2019-02-07; fcst is 0.0; obs is 0.0; cf is 0.86; bc_fcst is 0.0
# date is 2019-02-08; fcst is 0.03; obs is 0.0; cf is 0.86; bc_fcst is 0.04
# date is 2019-02-09; fcst is 0.46; obs is 0.42; cf is 0.86; bc_fcst is 0.54
# date is 2019-02-10; fcst is 0.23; obs is 0.05; cf is 0.86; bc_fcst is 0.27
# date is 2019-02-11; fcst is 0.33; obs is 0.41; cf is 0.99; bc_fcst is 0.33
# date is 2019-02-12; fcst is 0.49; obs is 0.45; cf is 0.98; bc_fcst is 0.5
# date is 2019-02-13; fcst is 0.35; obs is 0.64; cf is 0.99; bc_fcst is 0.35
# date is 2019-02-14; fcst is 0.01; obs is 0.29; cf is 0.97; bc_fcst is 0.01
# date is 2019-02-15; fcst is 0.15; obs is 0.34; cf is 0.94; bc_fcst is 0.16
# date is 2019-02-16; fcst is 0.15; obs is 0.04; cf is 0.92; bc_fcst is 0.16
# date is 2019-02-17; fcst is 0.38; obs is 0.11; cf is 1.02; bc_fcst is 0.37
# date is 2019-02-18; fcst is 0.04; obs is 0.18; cf is 1.1; bc_fcst is 0.04
# date is 2019-02-19; fcst is 0.0; obs is 0.0; cf is 1.07; bc_fcst is 0.0
# date is 2019-02-20; fcst is 0.42; obs is 0.31; cf is 1.07; bc_fcst is 0.39
# date is 2019-02-21; fcst is 0.0; obs is 0.1; cf is 1.08; bc_fcst is 0.0
# date is 2019-02-22; fcst is 0.0; obs is 0.0; cf is 1.04; bc_fcst is 0.0
# date is 2019-02-23; fcst is 0.33; obs is 0.3; cf is 1.04; bc_fcst is 0.32
# date is 2019-02-24; fcst is 0.19; obs is 0.05; cf is 1.05; bc_fcst is 0.18
# date is 2019-02-25; fcst is 0.01; obs is 0.18; cf is 1.14; bc_fcst is 0.01
# date is 2019-02-26; fcst is 0.0; obs is 0.0; cf is 1.1; bc_fcst is 0.0
# date is 2019-02-27; fcst is 0.0; obs is 0.0; cf is 1.1; bc_fcst is 0.0
# date is 2019-02-28; fcst is 0.03; obs is 0.01; cf is 1.1; bc_fcst is 0.03
# date is 2019-03-01; fcst is 0.0; obs is 0.0; cf is 1.1; bc_fcst is 0.0
# date is 2019-03-02; fcst is 0.0; obs is 0.0; cf is 1.1; bc_fcst is 0.0
# date is 2019-03-03; fcst is 0.0; obs is 0.0; cf is 1.1; bc_fcst is 0.0
# date is 2019-03-04; fcst is 0.0; obs is 0.0; cf is 1.1; bc_fcst is 0.0
# date is 2019-03-05; fcst is 0.0; obs is 0.0; cf is 1.1; bc_fcst is 0.0
# date is 2019-03-06; fcst is 0.0; obs is 0.0; cf is 1.1; bc_fcst is 0.0
# date is 2019-03-07; fcst is 0.0; obs is 0.0; cf is 1.1; bc_fcst is 0.0
# date is 2019-03-08; fcst is 0.55; obs is 0.21; cf is 1.1; bc_fcst is 0.5
# date is 2019-03-09; fcst is 0.02; obs is 0.01; cf is 1.15; bc_fcst is 0.02
# date is 2019-03-10; fcst is 0.0; obs is 0.0; cf is 1.15; bc_fcst is 0.0
# date is 2019-03-11; fcst is 0.0; obs is 0.0; cf is 1.15; bc_fcst is 0.0
# date is 2019-03-12; fcst is 0.52; obs is 0.23; cf is 1.15; bc_fcst is 0.45
# date is 2019-03-13; fcst is 0.0; obs is 0.06; cf is 1.19; bc_fcst is 0.0
# date is 2019-03-14; fcst is 0.0; obs is 0.0; cf is 1.15; bc_fcst is 0.0
# date is 2019-03-15; fcst is 0.0; obs is 0.01; cf is 1.15; bc_fcst is 0.0
# date is 2019-03-16; fcst is 0.0; obs is 0.0; cf is 1.15; bc_fcst is 0.0
# date is 2019-03-17; fcst is 0.0; obs is 0.0; cf is 1.15; bc_fcst is 0.0
# date is 2019-03-18; fcst is 0.0; obs is 0.0; cf is 1.15; bc_fcst is 0.0
# date is 2019-03-19; fcst is 0.0; obs is 0.0; cf is 1.15; bc_fcst is 0.0
# date is 2019-03-20; fcst is 0.0; obs is 0.0; cf is 1.15; bc_fcst is 0.0
# date is 2019-03-21; fcst is 0.0; obs is 0.0; cf is 1.15; bc_fcst is 0.0
# date is 2019-03-22; fcst is 0.0; obs is 0.0; cf is 1.15; bc_fcst is 0.0
# date is 2019-03-23; fcst is 0.01; obs is 0.01; cf is 1.15; bc_fcst is 0.01
# date is 2019-03-24; fcst is 0.0; obs is 0.02; cf is 1.15; bc_fcst is 0.0
# date is 2019-03-25; fcst is 0.0; obs is 0.0; cf is 1.11; bc_fcst is 0.0
# date is 2019-03-26; fcst is 0.2; obs is 0.24; cf is 1.11; bc_fcst is 0.18
# date is 2019-03-27; fcst is 0.1; obs is 0.05; cf is 1.1; bc_fcst is 0.09
# date is 2019-03-28; fcst is 0.01; obs is 0.0; cf is 1.13; bc_fcst is 0.01
# date is 2019-03-29; fcst is 0.0; obs is 0.0; cf is 1.13; bc_fcst is 0.0
# date is 2019-03-30; fcst is 0.0; obs is 0.0; cf is 1.13; bc_fcst is 0.0
# date is 2019-03-31; fcst is 0.0; obs is 0.0; cf is 1.13; bc_fcst is 0.0
# date is 2019-04-01; fcst is 0.0; obs is 0.0; cf is 1.13; bc_fcst is 0.0
# date is 2019-04-02; fcst is 0.0; obs is 0.0; cf is 1.13; bc_fcst is 0.0
# date is 2019-04-03; fcst is 0.16; obs is 0.06; cf is 1.13; bc_fcst is 0.14
# date is 2019-04-04; fcst is 0.02; obs is 0.04; cf is 1.18; bc_fcst is 0.02
# date is 2019-04-05; fcst is 0.05; obs is 0.02; cf is 1.16; bc_fcst is 0.04
# date is 2019-04-06; fcst is 0.12; obs is 0.38; cf is 1.2; bc_fcst is 0.1
# date is 2019-04-07; fcst is 0.36; obs is 0.91; cf is 1.18; bc_fcst is 0.31
# date is 2019-04-08; fcst is 0.0; obs is 0.1; cf is 1.15; bc_fcst is 0.0
# date is 2019-04-09; fcst is 0.21; obs is 0.63; cf is 1.11; bc_fcst is 0.19
# date is 2019-04-10; fcst is 0.02; obs is 0.01; cf is 1.08; bc_fcst is 0.02
# date is 2019-04-11; fcst is 0.39; obs is 0.23; cf is 1.08; bc_fcst is 0.36
# date is 2019-04-12; fcst is 0.35; obs is 0.17; cf is 1.11; bc_fcst is 0.32
# date is 2019-04-13; fcst is 0.01; obs is 0.0; cf is 1.14; bc_fcst is 0.01
# date is 2019-04-14; fcst is 0.2; obs is 0.47; cf is 1.14; bc_fcst is 0.18
# date is 2019-04-15; fcst is 0.2; obs is 0.06; cf is 1.11; bc_fcst is 0.18
# date is 2019-04-16; fcst is 0.15; obs is 0.0; cf is 1.19; bc_fcst is 0.13
# date is 2019-04-17; fcst is 0.0; obs is 0.0; cf is 1.19; bc_fcst is 0.0
# date is 2019-04-18; fcst is 0.03; obs is 0.02; cf is 1.19; bc_fcst is 0.03
# date is 2019-04-19; fcst is 0.07; obs is 0.78; cf is 1.2; bc_fcst is 0.06
# date is 2019-04-20; fcst is 0.04; obs is 0.04; cf is 1.16; bc_fcst is 0.03
# date is 2019-04-21; fcst is 0.0; obs is 0.0; cf is 1.16; bc_fcst is 0.0
# date is 2019-04-22; fcst is 0.0; obs is 0.0; cf is 1.16; bc_fcst is 0.0
# date is 2019-04-23; fcst is 0.17; obs is 0.28; cf is 1.16; bc_fcst is 0.15
# date is 2019-04-24; fcst is 0.0; obs is 0.0; cf is 1.14; bc_fcst is 0.0
# date is 2019-04-25; fcst is 0.0; obs is 0.0; cf is 1.14; bc_fcst is 0.0
# date is 2019-04-26; fcst is 0.0; obs is 0.0; cf is 1.14; bc_fcst is 0.0
# date is 2019-04-27; fcst is 0.02; obs is 0.0; cf is 1.14; bc_fcst is 0.02
# date is 2019-04-28; fcst is 0.05; obs is 0.0; cf is 1.14; bc_fcst is 0.04
# date is 2019-04-29; fcst is 0.0; obs is 0.0; cf is 1.14; bc_fcst is 0.0
# date is 2018-12-11; fcst is 0.64; obs is 0.79; cf is 1.0; bc_fcst is 0.64
# date is 2018-12-12; fcst is 3.0; obs is 2.18; cf is 0.99; bc_fcst is 3.02
# date is 2018-12-13; fcst is 2.81; obs is 1.8; cf is 1.01; bc_fcst is 2.79
# date is 2018-12-14; fcst is 2.18; obs is 2.06; cf is 1.02; bc_fcst is 2.13
# date is 2018-12-15; fcst is 0.88; obs is 0.39; cf is 1.03; bc_fcst is 0.86
# date is 2018-12-16; fcst is 0.97; obs is 0.63; cf is 1.07; bc_fcst is 0.91
# date is 2018-12-17; fcst is 3.43; obs is 3.88; cf is 1.08; bc_fcst is 3.17
# date is 2018-12-18; fcst is 2.9; obs is 2.19; cf is 1.08; bc_fcst is 2.69
# date is 2018-12-19; fcst is 2.08; obs is 1.4; cf is 1.08; bc_fcst is 1.92
# date is 2018-12-20; fcst is 1.3; obs is 1.22; cf is 1.1; bc_fcst is 1.18
# date is 2018-12-21; fcst is 2.71; obs is 2.48; cf is 1.1; bc_fcst is 2.47
# date is 2018-12-22; fcst is 0.29; obs is 0.1; cf is 1.1; bc_fcst is 0.26
# date is 2018-12-23; fcst is 2.12; obs is 1.19; cf is 1.16; bc_fcst is 1.83
# date is 2018-12-24; fcst is 0.15; obs is 0.72; cf is 1.18; bc_fcst is 0.13
# date is 2018-12-25; fcst is 0.0; obs is 0.0; cf is 1.15; bc_fcst is 0.0
# date is 2018-12-26; fcst is 0.04; obs is 0.0; cf is 1.15; bc_fcst is 0.03
# date is 2018-12-27; fcst is 0.97; obs is 0.23; cf is 1.15; bc_fcst is 0.85
# date is 2018-12-28; fcst is 0.0; obs is 0.03; cf is 1.25; bc_fcst is 0.0
# date is 2018-12-29; fcst is 0.79; obs is 0.73; cf is 1.21; bc_fcst is 0.66
# date is 2018-12-30; fcst is 0.71; obs is 1.83; cf is 1.2; bc_fcst is 0.59
# date is 2018-12-31; fcst is 0.02; obs is 0.0; cf is 1.17; bc_fcst is 0.02
# date is 2019-01-01; fcst is 0.0; obs is 0.0; cf is 1.17; bc_fcst is 0.0
# date is 2019-01-02; fcst is 0.0; obs is 0.0; cf is 1.17; bc_fcst is 0.0
# date is 2019-01-03; fcst is 1.29; obs is 1.41; cf is 1.17; bc_fcst is 1.1
# date is 2019-01-04; fcst is 4.84; obs is 4.14; cf is 1.17; bc_fcst is 4.15
# date is 2019-01-05; fcst is 1.54; obs is 1.07; cf is 1.17; bc_fcst is 1.32
# date is 2019-01-06; fcst is 0.79; obs is 0.43; cf is 1.18; bc_fcst is 0.67
# date is 2019-01-07; fcst is 1.96; obs is 0.87; cf is 1.2; bc_fcst is 1.64
# date is 2019-01-08; fcst is 0.09; obs is 0.28; cf is 1.23; bc_fcst is 0.07
# date is 2019-01-09; fcst is 1.43; obs is 1.31; cf is 1.2; bc_fcst is 1.19
# date is 2019-01-10; fcst is 3.58; obs is 2.62; cf is 1.2; bc_fcst is 2.99
# date is 2019-01-11; fcst is 0.77; obs is 0.62; cf is 1.2; bc_fcst is 0.64
# date is 2019-01-12; fcst is 0.0; obs is 0.0; cf is 1.21; bc_fcst is 0.0
# date is 2019-01-13; fcst is 0.0; obs is 0.0; cf is 1.21; bc_fcst is 0.0
# date is 2019-01-14; fcst is 0.0; obs is 0.0; cf is 1.21; bc_fcst is 0.0
# date is 2019-01-15; fcst is 0.0; obs is 0.0; cf is 1.21; bc_fcst is 0.0
# date is 2019-01-16; fcst is 0.0; obs is 0.0; cf is 1.21; bc_fcst is 0.0
# date is 2019-01-17; fcst is 0.0; obs is 0.0; cf is 1.21; bc_fcst is 0.0
# date is 2019-01-18; fcst is 2.09; obs is 1.29; cf is 1.21; bc_fcst is 1.73
# date is 2019-01-19; fcst is 1.97; obs is 1.3; cf is 1.22; bc_fcst is 1.62
# date is 2019-01-20; fcst is 0.15; obs is 0.41; cf is 1.23; bc_fcst is 0.12
# date is 2019-01-21; fcst is 0.0; obs is 0.0; cf is 1.2; bc_fcst is 0.0
# date is 2019-01-22; fcst is 0.03; obs is 0.02; cf is 1.2; bc_fcst is 0.02
# date is 2019-01-23; fcst is 1.68; obs is 1.2; cf is 1.21; bc_fcst is 1.39
# date is 2019-01-24; fcst is 0.14; obs is 0.1; cf is 1.22; bc_fcst is 0.12
# date is 2019-01-25; fcst is 0.0; obs is 0.0; cf is 1.22; bc_fcst is 0.0
# date is 2019-01-26; fcst is 0.0; obs is 0.0; cf is 1.22; bc_fcst is 0.0
# date is 2019-01-27; fcst is 0.0; obs is 0.0; cf is 1.22; bc_fcst is 0.0
# date is 2019-01-28; fcst is 0.0; obs is 0.0; cf is 1.22; bc_fcst is 0.0
# date is 2019-01-29; fcst is 0.0; obs is 0.0; cf is 1.22; bc_fcst is 0.0
# date is 2019-01-30; fcst is 0.0; obs is 0.0; cf is 1.22; bc_fcst is 0.0
# date is 2019-01-31; fcst is 0.0; obs is 0.0; cf is 1.22; bc_fcst is 0.0
# date is 2019-02-01; fcst is 0.94; obs is 0.72; cf is 1.22; bc_fcst is 0.77
# date is 2019-02-02; fcst is 2.64; obs is 2.54; cf is 1.23; bc_fcst is 2.15
# date is 2019-02-03; fcst is 0.08; obs is 0.26; cf is 1.22; bc_fcst is 0.07
# date is 2019-02-04; fcst is 0.45; obs is 0.42; cf is 1.19; bc_fcst is 0.38
# date is 2019-02-05; fcst is 0.0; obs is 0.01; cf is 1.18; bc_fcst is 0.0
# date is 2019-02-06; fcst is 0.0; obs is 0.0; cf is 1.18; bc_fcst is 0.0
# date is 2019-02-07; fcst is 0.0; obs is 0.0; cf is 1.18; bc_fcst is 0.0
# date is 2019-02-08; fcst is 0.12; obs is 0.0; cf is 1.18; bc_fcst is 0.1
# date is 2019-02-09; fcst is 0.02; obs is 0.1; cf is 1.18; bc_fcst is 0.02
# date is 2019-02-10; fcst is 0.01; obs is 0.0; cf is 1.15; bc_fcst is 0.01
# date is 2019-02-11; fcst is 0.22; obs is 0.24; cf is 1.15; bc_fcst is 0.19
# date is 2019-02-12; fcst is 0.77; obs is 0.75; cf is 1.14; bc_fcst is 0.67
# date is 2019-02-13; fcst is 0.86; obs is 0.85; cf is 1.14; bc_fcst is 0.75
# date is 2019-02-14; fcst is 0.01; obs is 0.35; cf is 1.14; bc_fcst is 0.01
# date is 2019-02-15; fcst is 0.7; obs is 0.45; cf is 1.1; bc_fcst is 0.64
# date is 2019-02-16; fcst is 0.56; obs is 0.29; cf is 1.11; bc_fcst is 0.5
# date is 2019-02-17; fcst is 0.11; obs is 0.0; cf is 1.14; bc_fcst is 0.1
# date is 2019-02-18; fcst is 0.0; obs is 0.0; cf is 1.14; bc_fcst is 0.0
# date is 2019-02-19; fcst is 0.0; obs is 0.0; cf is 1.14; bc_fcst is 0.0
# date is 2019-02-20; fcst is 0.8; obs is 0.34; cf is 1.14; bc_fcst is 0.7
# date is 2019-02-21; fcst is 0.0; obs is 0.0; cf is 1.18; bc_fcst is 0.0
# date is 2019-02-22; fcst is 0.0; obs is 0.0; cf is 1.18; bc_fcst is 0.0
# date is 2019-02-23; fcst is 0.65; obs is 0.36; cf is 1.18; bc_fcst is 0.55
# date is 2019-02-24; fcst is 0.0; obs is 0.02; cf is 1.2; bc_fcst is 0.0
# date is 2019-02-25; fcst is 0.0; obs is 0.0; cf is 1.16; bc_fcst is 0.0
# date is 2019-02-26; fcst is 0.0; obs is 0.0; cf is 1.16; bc_fcst is 0.0
# date is 2019-02-27; fcst is 0.0; obs is 0.0; cf is 1.16; bc_fcst is 0.0
# date is 2019-02-28; fcst is 0.19; obs is 0.12; cf is 1.16; bc_fcst is 0.16
# date is 2019-03-01; fcst is 0.22; obs is 0.0; cf is 1.18; bc_fcst is 0.19
# date is 2019-03-02; fcst is 0.0; obs is 0.0; cf is 1.18; bc_fcst is 0.0
# date is 2019-03-03; fcst is 0.0; obs is 0.0; cf is 1.18; bc_fcst is 0.0
# date is 2019-03-04; fcst is 0.0; obs is 0.0; cf is 1.18; bc_fcst is 0.0
# date is 2019-03-05; fcst is 0.0; obs is 0.0; cf is 1.18; bc_fcst is 0.0
# date is 2019-03-06; fcst is 0.0; obs is 0.0; cf is 1.18; bc_fcst is 0.0
# date is 2019-03-07; fcst is 0.52; obs is 0.52; cf is 1.18; bc_fcst is 0.44
# date is 2019-03-08; fcst is 0.14; obs is 0.32; cf is 1.17; bc_fcst is 0.12
# date is 2019-03-09; fcst is 0.03; obs is 0.03; cf is 1.15; bc_fcst is 0.03
# date is 2019-03-10; fcst is 0.0; obs is 0.0; cf is 1.14; bc_fcst is 0.0
# date is 2019-03-11; fcst is 0.0; obs is 0.0; cf is 1.14; bc_fcst is 0.0
# date is 2019-03-12; fcst is 0.31; obs is 0.53; cf is 1.14; bc_fcst is 0.27
# date is 2019-03-13; fcst is 0.1; obs is 0.21; cf is 1.12; bc_fcst is 0.09
# date is 2019-03-14; fcst is 0.12; obs is 0.0; cf is 1.1; bc_fcst is 0.11
# date is 2019-03-15; fcst is 0.05; obs is 0.0; cf is 1.1; bc_fcst is 0.05
# date is 2019-03-16; fcst is 0.0; obs is 0.0; cf is 1.1; bc_fcst is 0.0
# date is 2019-03-17; fcst is 0.0; obs is 0.0; cf is 1.1; bc_fcst is 0.0
# date is 2019-03-18; fcst is 0.0; obs is 0.0; cf is 1.1; bc_fcst is 0.0
# date is 2019-03-19; fcst is 0.0; obs is 0.0; cf is 1.1; bc_fcst is 0.0
# date is 2019-03-20; fcst is 0.0; obs is 0.0; cf is 1.1; bc_fcst is 0.0
# date is 2019-03-21; fcst is 0.0; obs is 0.0; cf is 1.1; bc_fcst is 0.0
# date is 2019-03-22; fcst is 0.0; obs is 0.0; cf is 1.1; bc_fcst is 0.0
# date is 2019-03-23; fcst is 0.75; obs is 0.22; cf is 1.1; bc_fcst is 0.68
# date is 2019-03-24; fcst is 0.0; obs is 0.03; cf is 1.18; bc_fcst is 0.0
# date is 2019-03-25; fcst is 0.04; obs is 0.02; cf is 1.14; bc_fcst is 0.04
# date is 2019-03-26; fcst is 0.94; obs is 0.46; cf is 1.17; bc_fcst is 0.8
# date is 2019-03-27; fcst is 0.24; obs is 0.4; cf is 1.2; bc_fcst is 0.2
# date is 2019-03-28; fcst is 0.07; obs is 0.0; cf is 1.18; bc_fcst is 0.06
# date is 2019-03-29; fcst is 0.0; obs is 0.0; cf is 1.18; bc_fcst is 0.0
# date is 2019-03-30; fcst is 0.0; obs is 0.0; cf is 1.18; bc_fcst is 0.0
# date is 2019-03-31; fcst is 0.0; obs is 0.0; cf is 1.18; bc_fcst is 0.0
# date is 2019-04-01; fcst is 0.0; obs is 0.0; cf is 1.18; bc_fcst is 0.0
# date is 2019-04-02; fcst is 0.0; obs is 0.0; cf is 1.18; bc_fcst is 0.0
# date is 2019-04-03; fcst is 0.18; obs is 0.19; cf is 1.18; bc_fcst is 0.15
# date is 2019-04-04; fcst is 0.74; obs is 1.64; cf is 1.17; bc_fcst is 0.63
# date is 2019-04-05; fcst is 0.0; obs is 0.13; cf is 1.15; bc_fcst is 0.0
# date is 2019-04-06; fcst is 0.7; obs is 1.12; cf is 1.11; bc_fcst is 0.63
# date is 2019-04-07; fcst is 2.12; obs is 0.68; cf is 1.09; bc_fcst is 1.94
# date is 2019-04-08; fcst is 0.03; obs is 0.23; cf is 1.16; bc_fcst is 0.03
# date is 2019-04-09; fcst is 0.52; obs is 0.42; cf is 1.12; bc_fcst is 0.46
# date is 2019-04-10; fcst is 0.09; obs is 0.08; cf is 1.13; bc_fcst is 0.08
# date is 2019-04-11; fcst is 0.84; obs is 0.56; cf is 1.13; bc_fcst is 0.74
# date is 2019-04-12; fcst is 0.3; obs is 0.23; cf is 1.14; bc_fcst is 0.26
# date is 2019-04-13; fcst is 0.0; obs is 0.07; cf is 1.15; bc_fcst is 0.0
# date is 2019-04-14; fcst is 1.58; obs is 0.94; cf is 1.11; bc_fcst is 1.43
# date is 2019-04-15; fcst is 0.2; obs is 0.36; cf is 1.13; bc_fcst is 0.18
# date is 2019-04-16; fcst is 0.0; obs is 0.0; cf is 1.11; bc_fcst is 0.0
# date is 2019-04-17; fcst is 0.22; obs is 0.52; cf is 1.11; bc_fcst is 0.2
# date is 2019-04-18; fcst is 0.08; obs is 0.09; cf is 1.09; bc_fcst is 0.07
# date is 2019-04-19; fcst is 0.5; obs is 1.47; cf is 1.08; bc_fcst is 0.46
# date is 2019-04-20; fcst is 0.61; obs is 0.79; cf is 1.05; bc_fcst is 0.58
# date is 2019-04-21; fcst is 0.0; obs is 0.0; cf is 1.04; bc_fcst is 0.0
# date is 2019-04-22; fcst is 0.0; obs is 0.0; cf is 1.04; bc_fcst is 0.0
# date is 2019-04-23; fcst is 0.09; obs is 0.2; cf is 1.04; bc_fcst is 0.09
# date is 2019-04-24; fcst is 0.01; obs is 0.78; cf is 1.02; bc_fcst is 0.01
# date is 2019-04-25; fcst is 0.0; obs is 0.0; cf is 0.99; bc_fcst is 0.0
# date is 2019-04-26; fcst is 0.0; obs is 0.0; cf is 0.99; bc_fcst is 0.0
# date is 2019-04-27; fcst is 0.28; obs is 0.34; cf is 0.99; bc_fcst is 0.28
# date is 2019-04-28; fcst is 0.01; obs is 0.45; cf is 0.99; bc_fcst is 0.01
# date is 2019-04-29; fcst is 0.0; obs is 0.0; cf is 0.95; bc_fcst is 0.0
# date is 2018-12-11; fcst is 0.2; obs is 0.11; cf is 1.0; bc_fcst is 0.2
# date is 2018-12-12; fcst is 2.34; obs is 1.5; cf is 1.03; bc_fcst is 2.28
# date is 2018-12-13; fcst is 1.19; obs is 0.31; cf is 1.05; bc_fcst is 1.14
# date is 2018-12-14; fcst is 1.45; obs is 0.24; cf is 1.14; bc_fcst is 1.27
# date is 2018-12-15; fcst is 0.24; obs is 0.21; cf is 1.3; bc_fcst is 0.18
# date is 2018-12-16; fcst is 0.4; obs is 0.2; cf is 1.3; bc_fcst is 0.31
# date is 2018-12-17; fcst is 0.9; obs is 0.44; cf is 1.32; bc_fcst is 0.68
# date is 2018-12-18; fcst is 1.29; obs is 0.55; cf is 1.34; bc_fcst is 0.96
# date is 2018-12-19; fcst is 1.77; obs is 0.91; cf is 1.38; bc_fcst is 1.29
# date is 2018-12-20; fcst is 0.45; obs is 0.22; cf is 1.4; bc_fcst is 0.32
# date is 2018-12-21; fcst is 0.68; obs is 0.65; cf is 1.42; bc_fcst is 0.48
# date is 2018-12-22; fcst is 0.02; obs is 0.01; cf is 1.41; bc_fcst is 0.01
# date is 2018-12-23; fcst is 0.5; obs is 0.18; cf is 1.41; bc_fcst is 0.36
# date is 2018-12-24; fcst is 0.69; obs is 0.17; cf is 1.45; bc_fcst is 0.48
# date is 2018-12-25; fcst is 0.0; obs is 0.0; cf is 1.54; bc_fcst is 0.0
# date is 2018-12-26; fcst is 0.0; obs is 0.0; cf is 1.54; bc_fcst is 0.0
# date is 2018-12-27; fcst is 0.3; obs is 0.1; cf is 1.54; bc_fcst is 0.2
# date is 2018-12-28; fcst is 0.0; obs is 0.0; cf is 1.59; bc_fcst is 0.0
# date is 2018-12-29; fcst is 0.42; obs is 0.12; cf is 1.59; bc_fcst is 0.26
# date is 2018-12-30; fcst is 0.82; obs is 0.53; cf is 1.65; bc_fcst is 0.5
# date is 2018-12-31; fcst is 0.03; obs is 0.13; cf is 1.65; bc_fcst is 0.02
# date is 2019-01-01; fcst is 0.0; obs is 0.0; cf is 1.6; bc_fcst is 0.0
# date is 2019-01-02; fcst is 0.0; obs is 0.0; cf is 1.6; bc_fcst is 0.0
# date is 2019-01-03; fcst is 0.4; obs is 0.25; cf is 1.6; bc_fcst is 0.25
# date is 2019-01-04; fcst is 2.15; obs is 0.72; cf is 1.6; bc_fcst is 1.34
# date is 2019-01-05; fcst is 0.24; obs is 0.1; cf is 1.65; bc_fcst is 0.15
# date is 2019-01-06; fcst is 0.27; obs is 0.13; cf is 1.67; bc_fcst is 0.16
# date is 2019-01-07; fcst is 0.62; obs is 0.22; cf is 1.68; bc_fcst is 0.37
# date is 2019-01-08; fcst is 0.06; obs is 0.04; cf is 1.72; bc_fcst is 0.03
# date is 2019-01-09; fcst is 0.6; obs is 0.24; cf is 1.72; bc_fcst is 0.35
# date is 2019-01-10; fcst is 0.78; obs is 0.46; cf is 1.74; bc_fcst is 0.45
# date is 2019-01-11; fcst is 0.19; obs is 0.04; cf is 1.74; bc_fcst is 0.11
# date is 2019-01-12; fcst is 0.0; obs is 0.0; cf is 1.84; bc_fcst is 0.0
# date is 2019-01-13; fcst is 0.0; obs is 0.0; cf is 1.84; bc_fcst is 0.0
# date is 2019-01-14; fcst is 0.0; obs is 0.0; cf is 1.84; bc_fcst is 0.0
# date is 2019-01-15; fcst is 0.0; obs is 0.0; cf is 1.84; bc_fcst is 0.0
# date is 2019-01-16; fcst is 0.0; obs is 0.01; cf is 1.84; bc_fcst is 0.0
# date is 2019-01-17; fcst is 0.0; obs is 0.02; cf is 1.84; bc_fcst is 0.0
# date is 2019-01-18; fcst is 0.62; obs is 0.22; cf is 1.78; bc_fcst is 0.35
# date is 2019-01-19; fcst is 0.67; obs is 0.47; cf is 1.81; bc_fcst is 0.37
# date is 2019-01-20; fcst is 0.26; obs is 0.37; cf is 1.8; bc_fcst is 0.14
# date is 2019-01-21; fcst is 0.0; obs is 0.02; cf is 1.76; bc_fcst is 0.0
# date is 2019-01-22; fcst is 0.0; obs is 0.02; cf is 1.71; bc_fcst is 0.0
# date is 2019-01-23; fcst is 1.55; obs is 0.65; cf is 1.65; bc_fcst is 0.94
# date is 2019-01-24; fcst is 0.14; obs is 0.16; cf is 1.67; bc_fcst is 0.08
# date is 2019-01-25; fcst is 0.0; obs is 0.0; cf is 1.65; bc_fcst is 0.0
# date is 2019-01-26; fcst is 0.0; obs is 0.0; cf is 1.65; bc_fcst is 0.0
# date is 2019-01-27; fcst is 0.0; obs is 0.0; cf is 1.65; bc_fcst is 0.0
# date is 2019-01-28; fcst is 0.0; obs is 0.0; cf is 1.65; bc_fcst is 0.0
# date is 2019-01-29; fcst is 0.0; obs is 0.0; cf is 1.65; bc_fcst is 0.0
# date is 2019-01-30; fcst is 0.0; obs is 0.0; cf is 1.65; bc_fcst is 0.0
# date is 2019-01-31; fcst is 0.0; obs is 0.0; cf is 1.65; bc_fcst is 0.0
# date is 2019-02-01; fcst is 0.17; obs is 0.04; cf is 1.65; bc_fcst is 0.1
# date is 2019-02-02; fcst is 0.75; obs is 0.26; cf is 1.73; bc_fcst is 0.43
# date is 2019-02-03; fcst is 0.01; obs is 0.0; cf is 1.77; bc_fcst is 0.01
# date is 2019-02-04; fcst is 0.13; obs is 0.02; cf is 1.77; bc_fcst is 0.07
# date is 2019-02-05; fcst is 0.06; obs is 0.04; cf is 1.93; bc_fcst is 0.03
# date is 2019-02-06; fcst is 0.0; obs is 0.0; cf is 1.91; bc_fcst is 0.0
# date is 2019-02-07; fcst is 0.0; obs is 0.0; cf is 1.91; bc_fcst is 0.0
# date is 2019-02-08; fcst is 0.02; obs is 0.0; cf is 1.91; bc_fcst is 0.01
# date is 2019-02-09; fcst is 0.23; obs is 0.18; cf is 1.91; bc_fcst is 0.12
# date is 2019-02-10; fcst is 0.15; obs is 0.17; cf is 1.89; bc_fcst is 0.08
# date is 2019-02-11; fcst is 0.1; obs is 0.06; cf is 1.86; bc_fcst is 0.05
# date is 2019-02-12; fcst is 0.44; obs is 0.44; cf is 1.85; bc_fcst is 0.24
# date is 2019-02-13; fcst is 0.68; obs is 0.81; cf is 1.82; bc_fcst is 0.37
# date is 2019-02-14; fcst is 0.05; obs is 0.04; cf is 1.79; bc_fcst is 0.03
# date is 2019-02-15; fcst is 0.19; obs is 0.16; cf is 1.77; bc_fcst is 0.11
# date is 2019-02-16; fcst is 0.13; obs is 0.02; cf is 1.75; bc_fcst is 0.07
# date is 2019-02-17; fcst is 0.01; obs is 0.02; cf is 1.91; bc_fcst is 0.01
# date is 2019-02-18; fcst is 0.0; obs is 0.0; cf is 1.87; bc_fcst is 0.0
# date is 2019-02-19; fcst is 0.0; obs is 0.0; cf is 1.87; bc_fcst is 0.0
# date is 2019-02-20; fcst is 0.25; obs is 0.05; cf is 1.87; bc_fcst is 0.13
# date is 2019-02-21; fcst is 0.03; obs is 0.0; cf is 1.97; bc_fcst is 0.02
# date is 2019-02-22; fcst is 0.0; obs is 0.0; cf is 1.97; bc_fcst is 0.0
# date is 2019-02-23; fcst is 0.35; obs is 0.21; cf is 1.97; bc_fcst is 0.18
# date is 2019-02-24; fcst is 0.02; obs is 0.02; cf is 1.96; bc_fcst is 0.01
# date is 2019-02-25; fcst is 0.03; obs is 0.05; cf is 1.93; bc_fcst is 0.02
# date is 2019-02-26; fcst is 0.0; obs is 0.0; cf is 1.88; bc_fcst is 0.0
# date is 2019-02-27; fcst is 0.0; obs is 0.02; cf is 1.88; bc_fcst is 0.0
# date is 2019-02-28; fcst is 0.03; obs is 0.12; cf is 1.82; bc_fcst is 0.02
# date is 2019-03-01; fcst is 0.02; obs is 0.0; cf is 1.77; bc_fcst is 0.01
# date is 2019-03-02; fcst is 0.0; obs is 0.0; cf is 1.77; bc_fcst is 0.0
# date is 2019-03-03; fcst is 0.03; obs is 0.02; cf is 1.77; bc_fcst is 0.02
# date is 2019-03-04; fcst is 0.0; obs is 0.0; cf is 1.76; bc_fcst is 0.0
# date is 2019-03-05; fcst is 0.0; obs is 0.0; cf is 1.76; bc_fcst is 0.0
# date is 2019-03-06; fcst is 0.0; obs is 0.01; cf is 1.76; bc_fcst is 0.0
# date is 2019-03-07; fcst is 0.25; obs is 0.15; cf is 1.76; bc_fcst is 0.14
# date is 2019-03-08; fcst is 0.13; obs is 0.01; cf is 1.76; bc_fcst is 0.07
# date is 2019-03-09; fcst is 0.04; obs is 0.0; cf is 1.76; bc_fcst is 0.02
# date is 2019-03-10; fcst is 0.0; obs is 0.0; cf is 1.76; bc_fcst is 0.0
# date is 2019-03-11; fcst is 0.0; obs is 0.0; cf is 1.76; bc_fcst is 0.0
# date is 2019-03-12; fcst is 0.63; obs is 0.12; cf is 1.76; bc_fcst is 0.36
# date is 2019-03-13; fcst is 0.19; obs is 0.11; cf is 1.87; bc_fcst is 0.1
# date is 2019-03-14; fcst is 0.0; obs is 0.01; cf is 1.87; bc_fcst is 0.0
# date is 2019-03-15; fcst is 0.0; obs is 0.0; cf is 1.87; bc_fcst is 0.0
# date is 2019-03-16; fcst is 0.0; obs is 0.0; cf is 1.87; bc_fcst is 0.0
# date is 2019-03-17; fcst is 0.0; obs is 0.0; cf is 1.87; bc_fcst is 0.0
# date is 2019-03-18; fcst is 0.0; obs is 0.0; cf is 1.87; bc_fcst is 0.0
# date is 2019-03-19; fcst is 0.0; obs is 0.0; cf is 1.87; bc_fcst is 0.0
# date is 2019-03-20; fcst is 0.0; obs is 0.0; cf is 1.87; bc_fcst is 0.0
# date is 2019-03-21; fcst is 0.0; obs is 0.0; cf is 1.87; bc_fcst is 0.0
# date is 2019-03-22; fcst is 0.0; obs is 0.0; cf is 1.87; bc_fcst is 0.0
# date is 2019-03-23; fcst is 0.01; obs is 0.01; cf is 1.87; bc_fcst is 0.01
# date is 2019-03-24; fcst is 0.0; obs is 0.03; cf is 1.87; bc_fcst is 0.0
# date is 2019-03-25; fcst is 0.1; obs is 0.28; cf is 1.81; bc_fcst is 0.06
# date is 2019-03-26; fcst is 0.28; obs is 0.24; cf is 1.76; bc_fcst is 0.16
# date is 2019-03-27; fcst is 0.02; obs is 0.04; cf is 1.74; bc_fcst is 0.01
# date is 2019-03-28; fcst is 0.02; obs is 0.0; cf is 1.7; bc_fcst is 0.01
# date is 2019-03-29; fcst is 0.01; obs is 0.0; cf is 1.7; bc_fcst is 0.01
# date is 2019-03-30; fcst is 0.0; obs is 0.0; cf is 1.7; bc_fcst is 0.0
# date is 2019-03-31; fcst is 0.0; obs is 0.0; cf is 1.7; bc_fcst is 0.0
# date is 2019-04-01; fcst is 0.0; obs is 0.01; cf is 1.7; bc_fcst is 0.0
# date is 2019-04-02; fcst is 0.0; obs is 0.0; cf is 1.7; bc_fcst is 0.0
# date is 2019-04-03; fcst is 0.02; obs is 0.0; cf is 1.7; bc_fcst is 0.01
# date is 2019-04-04; fcst is 0.46; obs is 0.05; cf is 1.7; bc_fcst is 0.27
# date is 2019-04-05; fcst is 0.01; obs is 0.02; cf is 1.95; bc_fcst is 0.01
# date is 2019-04-06; fcst is 0.33; obs is 0.24; cf is 1.9; bc_fcst is 0.17
# date is 2019-04-07; fcst is 0.61; obs is 0.31; cf is 1.88; bc_fcst is 0.32
# date is 2019-04-08; fcst is 0.06; obs is 0.06; cf is 1.88; bc_fcst is 0.03
# date is 2019-04-09; fcst is 0.37; obs is 0.09; cf is 1.85; bc_fcst is 0.2
# date is 2019-04-10; fcst is 0.05; obs is 0.06; cf is 1.93; bc_fcst is 0.03
# date is 2019-04-11; fcst is 0.13; obs is 0.08; cf is 1.89; bc_fcst is 0.07
# date is 2019-04-12; fcst is 0.11; obs is 0.17; cf is 1.88; bc_fcst is 0.06
# date is 2019-04-13; fcst is 0.0; obs is 0.04; cf is 1.84; bc_fcst is 0.0
# date is 2019-04-14; fcst is 0.51; obs is 0.06; cf is 1.78; bc_fcst is 0.29
# date is 2019-04-15; fcst is 0.11; obs is 0.14; cf is 2.01; bc_fcst is 0.05
# date is 2019-04-16; fcst is 0.0; obs is 0.01; cf is 1.96; bc_fcst is 0.0
# date is 2019-04-17; fcst is 0.01; obs is 0.07; cf is 1.96; bc_fcst is 0.01
# date is 2019-04-18; fcst is 0.01; obs is 0.03; cf is 1.9; bc_fcst is 0.01
# date is 2019-04-19; fcst is 0.86; obs is 0.74; cf is 1.85; bc_fcst is 0.46
# date is 2019-04-20; fcst is 0.15; obs is 0.29; cf is 1.83; bc_fcst is 0.08
# date is 2019-04-21; fcst is 0.0; obs is 0.02; cf is 1.79; bc_fcst is 0.0
# date is 2019-04-22; fcst is 0.0; obs is 0.0; cf is 1.73; bc_fcst is 0.0
# date is 2019-04-23; fcst is 0.03; obs is 0.03; cf is 1.73; bc_fcst is 0.02
# date is 2019-04-24; fcst is 0.01; obs is 0.01; cf is 1.7; bc_fcst is 0.01
# date is 2019-04-25; fcst is 0.0; obs is 0.02; cf is 1.7; bc_fcst is 0.0
# date is 2019-04-26; fcst is 0.07; obs is 0.0; cf is 1.64; bc_fcst is 0.04
# date is 2019-04-27; fcst is 0.01; obs is 0.02; cf is 1.64; bc_fcst is 0.01
# date is 2019-04-28; fcst is 0.08; obs is 0.04; cf is 1.61; bc_fcst is 0.05
# date is 2019-04-29; fcst is 0.0; obs is 0.24; cf is 1.62; bc_fcst is 0.0
# date is 2018-12-11; fcst is 0.27; obs is 0.16; cf is 1.0; bc_fcst is 0.27
# date is 2018-12-12; fcst is 2.8; obs is 1.79; cf is 1.02; bc_fcst is 2.74
# date is 2018-12-13; fcst is 1.35; obs is 0.49; cf is 1.04; bc_fcst is 1.3
# date is 2018-12-14; fcst is 1.28; obs is 0.38; cf is 1.1; bc_fcst is 1.17
# date is 2018-12-15; fcst is 0.23; obs is 0.2; cf is 1.17; bc_fcst is 0.2
# date is 2018-12-16; fcst is 0.28; obs is 0.12; cf is 1.17; bc_fcst is 0.24
# date is 2018-12-17; fcst is 0.58; obs is 0.21; cf is 1.21; bc_fcst is 0.48
# date is 2018-12-18; fcst is 0.64; obs is 0.09; cf is 1.26; bc_fcst is 0.51
# date is 2018-12-19; fcst is 1.56; obs is 1.03; cf is 1.46; bc_fcst is 1.07
# date is 2018-12-20; fcst is 0.1; obs is 0.18; cf is 1.46; bc_fcst is 0.07
# date is 2018-12-21; fcst is 0.55; obs is 0.9; cf is 1.43; bc_fcst is 0.38
# date is 2018-12-22; fcst is 0.06; obs is 0.04; cf is 1.4; bc_fcst is 0.04
# date is 2018-12-23; fcst is 0.59; obs is 0.19; cf is 1.41; bc_fcst is 0.42
# date is 2018-12-24; fcst is 1.34; obs is 0.5; cf is 1.46; bc_fcst is 0.92
# date is 2018-12-25; fcst is 0.0; obs is 0.0; cf is 1.5; bc_fcst is 0.0
# date is 2018-12-26; fcst is 0.0; obs is 0.0; cf is 1.5; bc_fcst is 0.0
# date is 2018-12-27; fcst is 0.65; obs is 0.26; cf is 1.5; bc_fcst is 0.43
# date is 2018-12-28; fcst is 0.01; obs is 0.0; cf is 1.54; bc_fcst is 0.01
# date is 2018-12-29; fcst is 1.41; obs is 0.6; cf is 1.54; bc_fcst is 0.92
# date is 2018-12-30; fcst is 1.59; obs is 2.54; cf is 1.56; bc_fcst is 1.02
# date is 2018-12-31; fcst is 0.33; obs is 0.2; cf is 1.53; bc_fcst is 0.22
# date is 2019-01-01; fcst is 0.0; obs is 0.0; cf is 1.54; bc_fcst is 0.0
# date is 2019-01-02; fcst is 0.0; obs is 0.0; cf is 1.54; bc_fcst is 0.0
# date is 2019-01-03; fcst is 0.22; obs is 0.54; cf is 1.54; bc_fcst is 0.14
# date is 2019-01-04; fcst is 1.46; obs is 1.86; cf is 1.5; bc_fcst is 0.97
# date is 2019-01-05; fcst is 0.09; obs is 0.21; cf is 1.47; bc_fcst is 0.06
# date is 2019-01-06; fcst is 0.24; obs is 0.13; cf is 1.44; bc_fcst is 0.17
# date is 2019-01-07; fcst is 0.83; obs is 0.42; cf is 1.45; bc_fcst is 0.57
# date is 2019-01-08; fcst is 0.3; obs is 0.15; cf is 1.47; bc_fcst is 0.2
# date is 2019-01-09; fcst is 0.53; obs is 0.47; cf is 1.49; bc_fcst is 0.36
# date is 2019-01-10; fcst is 0.58; obs is 0.28; cf is 1.48; bc_fcst is 0.39
# date is 2019-01-11; fcst is 0.3; obs is 0.13; cf is 1.5; bc_fcst is 0.2
# date is 2019-01-12; fcst is 0.0; obs is 0.0; cf is 1.52; bc_fcst is 0.0
# date is 2019-01-13; fcst is 0.0; obs is 0.0; cf is 1.52; bc_fcst is 0.0
# date is 2019-01-14; fcst is 0.0; obs is 0.0; cf is 1.52; bc_fcst is 0.0
# date is 2019-01-15; fcst is 0.0; obs is 0.0; cf is 1.52; bc_fcst is 0.0
# date is 2019-01-16; fcst is 0.0; obs is 0.0; cf is 1.52; bc_fcst is 0.0
# date is 2019-01-17; fcst is 0.0; obs is 0.0; cf is 1.52; bc_fcst is 0.0
# date is 2019-01-18; fcst is 0.8; obs is 0.55; cf is 1.52; bc_fcst is 0.53
# date is 2019-01-19; fcst is 0.49; obs is 0.94; cf is 1.52; bc_fcst is 0.32
# date is 2019-01-20; fcst is 0.23; obs is 0.32; cf is 1.49; bc_fcst is 0.15
# date is 2019-01-21; fcst is 0.0; obs is 0.0; cf is 1.46; bc_fcst is 0.0
# date is 2019-01-22; fcst is 0.02; obs is 0.0; cf is 1.46; bc_fcst is 0.01
# date is 2019-01-23; fcst is 2.49; obs is 1.85; cf is 1.46; bc_fcst is 1.7
# date is 2019-01-24; fcst is 0.35; obs is 0.66; cf is 1.46; bc_fcst is 0.24
# date is 2019-01-25; fcst is 0.0; obs is 0.02; cf is 1.43; bc_fcst is 0.0
# date is 2019-01-26; fcst is 0.0; obs is 0.0; cf is 1.38; bc_fcst is 0.0
# date is 2019-01-27; fcst is 0.0; obs is 0.0; cf is 1.38; bc_fcst is 0.0
# date is 2019-01-28; fcst is 0.0; obs is 0.0; cf is 1.38; bc_fcst is 0.0
# date is 2019-01-29; fcst is 0.0; obs is 0.0; cf is 1.38; bc_fcst is 0.0
# date is 2019-01-30; fcst is 0.0; obs is 0.0; cf is 1.38; bc_fcst is 0.0
# date is 2019-01-31; fcst is 0.0; obs is 0.0; cf is 1.38; bc_fcst is 0.0
# date is 2019-02-01; fcst is 0.04; obs is 0.0; cf is 1.38; bc_fcst is 0.03
# date is 2019-02-02; fcst is 0.62; obs is 0.8; cf is 1.38; bc_fcst is 0.45
# date is 2019-02-03; fcst is 0.01; obs is 0.01; cf is 1.36; bc_fcst is 0.01
# date is 2019-02-04; fcst is 0.12; obs is 0.0; cf is 1.36; bc_fcst is 0.09
# date is 2019-02-05; fcst is 0.02; obs is 0.05; cf is 1.36; bc_fcst is 0.01
# date is 2019-02-06; fcst is 0.0; obs is 0.0; cf is 1.33; bc_fcst is 0.0
# date is 2019-02-07; fcst is 0.0; obs is 0.0; cf is 1.33; bc_fcst is 0.0
# date is 2019-02-08; fcst is 0.0; obs is 0.0; cf is 1.33; bc_fcst is 0.0
# date is 2019-02-09; fcst is 0.25; obs is 0.41; cf is 1.33; bc_fcst is 0.19
# date is 2019-02-10; fcst is 0.07; obs is 0.01; cf is 1.3; bc_fcst is 0.05
# date is 2019-02-11; fcst is 0.43; obs is 0.55; cf is 1.3; bc_fcst is 0.33
# date is 2019-02-12; fcst is 0.97; obs is 1.24; cf is 1.29; bc_fcst is 0.75
# date is 2019-02-13; fcst is 0.7; obs is 0.5; cf is 1.27; bc_fcst is 0.55
# date is 2019-02-14; fcst is 0.2; obs is 0.08; cf is 1.27; bc_fcst is 0.16
# date is 2019-02-15; fcst is 0.14; obs is 0.11; cf is 1.31; bc_fcst is 0.11
# date is 2019-02-16; fcst is 0.27; obs is 0.1; cf is 1.31; bc_fcst is 0.21
# date is 2019-02-17; fcst is 0.46; obs is 0.03; cf is 1.36; bc_fcst is 0.34
# date is 2019-02-18; fcst is 0.01; obs is 0.0; cf is 1.83; bc_fcst is 0.01
# date is 2019-02-19; fcst is 0.0; obs is 0.01; cf is 1.83; bc_fcst is 0.0
# date is 2019-02-20; fcst is 0.93; obs is 0.3; cf is 1.83; bc_fcst is 0.51
# date is 2019-02-21; fcst is 0.47; obs is 0.04; cf is 1.87; bc_fcst is 0.25
# date is 2019-02-22; fcst is 0.0; obs is 0.0; cf is 2.2; bc_fcst is 0.0
# date is 2019-02-23; fcst is 0.55; obs is 0.52; cf is 2.2; bc_fcst is 0.25
# date is 2019-02-24; fcst is 0.09; obs is 0.07; cf is 2.16; bc_fcst is 0.04
# date is 2019-02-25; fcst is 0.02; obs is 0.0; cf is 2.13; bc_fcst is 0.01
# date is 2019-02-26; fcst is 0.0; obs is 0.0; cf is 2.13; bc_fcst is 0.0
# date is 2019-02-27; fcst is 0.0; obs is 0.0; cf is 2.13; bc_fcst is 0.0
# date is 2019-02-28; fcst is 0.0; obs is 0.14; cf is 2.13; bc_fcst is 0.0
# date is 2019-03-01; fcst is 0.0; obs is 0.0; cf is 2.06; bc_fcst is 0.0
# date is 2019-03-02; fcst is 0.0; obs is 0.0; cf is 2.06; bc_fcst is 0.0
# date is 2019-03-03; fcst is 0.0; obs is 0.0; cf is 2.06; bc_fcst is 0.0
# date is 2019-03-04; fcst is 0.0; obs is 0.0; cf is 2.06; bc_fcst is 0.0
# date is 2019-03-05; fcst is 0.0; obs is 0.0; cf is 2.06; bc_fcst is 0.0
# date is 2019-03-06; fcst is 0.0; obs is 0.0; cf is 2.06; bc_fcst is 0.0
# date is 2019-03-07; fcst is 0.2; obs is 0.15; cf is 2.06; bc_fcst is 0.1
# date is 2019-03-08; fcst is 0.61; obs is 0.17; cf is 2.03; bc_fcst is 0.3
# date is 2019-03-09; fcst is 0.03; obs is 0.0; cf is 2.09; bc_fcst is 0.01
# date is 2019-03-10; fcst is 0.0; obs is 0.0; cf is 2.09; bc_fcst is 0.0
# date is 2019-03-11; fcst is 0.0; obs is 0.0; cf is 2.09; bc_fcst is 0.0
# date is 2019-03-12; fcst is 0.8; obs is 0.32; cf is 2.09; bc_fcst is 0.38
# date is 2019-03-13; fcst is 0.81; obs is 0.21; cf is 2.1; bc_fcst is 0.39
# date is 2019-03-14; fcst is 0.04; obs is 0.0; cf is 2.16; bc_fcst is 0.02
# date is 2019-03-15; fcst is 0.0; obs is 0.0; cf is 2.16; bc_fcst is 0.0
# date is 2019-03-16; fcst is 0.0; obs is 0.0; cf is 2.16; bc_fcst is 0.0
# date is 2019-03-17; fcst is 0.0; obs is 0.0; cf is 2.16; bc_fcst is 0.0
# date is 2019-03-18; fcst is 0.0; obs is 0.0; cf is 2.16; bc_fcst is 0.0
# date is 2019-03-19; fcst is 0.0; obs is 0.0; cf is 2.16; bc_fcst is 0.0
# date is 2019-03-20; fcst is 0.0; obs is 0.0; cf is 2.16; bc_fcst is 0.0
# date is 2019-03-21; fcst is 0.0; obs is 0.0; cf is 2.16; bc_fcst is 0.0
# date is 2019-03-22; fcst is 0.0; obs is 0.0; cf is 2.16; bc_fcst is 0.0
# date is 2019-03-23; fcst is 0.1; obs is 0.01; cf is 2.16; bc_fcst is 0.05
# date is 2019-03-24; fcst is 0.0; obs is 0.11; cf is 2.16; bc_fcst is 0.0
# date is 2019-03-25; fcst is 0.2; obs is 0.19; cf is 2.09; bc_fcst is 0.1
# date is 2019-03-26; fcst is 0.28; obs is 0.27; cf is 2.05; bc_fcst is 0.14
# date is 2019-03-27; fcst is 0.13; obs is 0.04; cf is 2.02; bc_fcst is 0.06
# date is 2019-03-28; fcst is 0.07; obs is 0.0; cf is 2.06; bc_fcst is 0.03
# date is 2019-03-29; fcst is 0.0; obs is nan; cf is 2.06; bc_fcst is 0.0
# date is 2019-03-30; fcst is 0.02; obs is 0.0; cf is 2.06; bc_fcst is 0.01
# date is 2019-03-31; fcst is 0.0; obs is 0.0; cf is 2.06; bc_fcst is 0.0
# date is 2019-04-01; fcst is 0.0; obs is 0.0; cf is 2.06; bc_fcst is 0.0
# date is 2019-04-02; fcst is 0.0; obs is 0.0; cf is 2.06; bc_fcst is 0.0
# date is 2019-04-03; fcst is 0.0; obs is 0.05; cf is 2.06; bc_fcst is 0.0
# date is 2019-04-04; fcst is 0.53; obs is 0.69; cf is 1.99; bc_fcst is 0.27
# date is 2019-04-05; fcst is 0.02; obs is 0.0; cf is 1.95; bc_fcst is 0.01
# date is 2019-04-06; fcst is 0.41; obs is 0.67; cf is 1.95; bc_fcst is 0.21
# date is 2019-04-07; fcst is 0.57; obs is 0.48; cf is 1.91; bc_fcst is 0.3
# date is 2019-04-08; fcst is 0.07; obs is 0.14; cf is 1.88; bc_fcst is 0.04
# date is 2019-04-09; fcst is 0.53; obs is 0.54; cf is 1.84; bc_fcst is 0.29
# date is 2019-04-10; fcst is 0.11; obs is 0.33; cf is 1.81; bc_fcst is 0.06
# date is 2019-04-11; fcst is 0.95; obs is 0.85; cf is 1.76; bc_fcst is 0.54
# date is 2019-04-12; fcst is 0.62; obs is 0.39; cf is 1.74; bc_fcst is 0.36
# date is 2019-04-13; fcst is 0.08; obs is 0.12; cf is 1.73; bc_fcst is 0.05
# date is 2019-04-14; fcst is 0.82; obs is 0.65; cf is 1.7; bc_fcst is 0.48
# date is 2019-04-15; fcst is 0.54; obs is 0.06; cf is 1.68; bc_fcst is 0.32
# date is 2019-04-16; fcst is 0.0; obs is 0.0; cf is 1.93; bc_fcst is 0.0
# date is 2019-04-17; fcst is 0.14; obs is 0.33; cf is 1.93; bc_fcst is 0.07
# date is 2019-04-18; fcst is 0.16; obs is 0.21; cf is 1.88; bc_fcst is 0.09
# date is 2019-04-19; fcst is 1.0; obs is 0.42; cf is 1.84; bc_fcst is 0.54
# date is 2019-04-20; fcst is 0.58; obs is 0.51; cf is 1.86; bc_fcst is 0.31
# date is 2019-04-21; fcst is 0.0; obs is 0.01; cf is 1.83; bc_fcst is 0.0
# date is 2019-04-22; fcst is 0.0; obs is 0.0; cf is 1.83; bc_fcst is 0.0
# date is 2019-04-23; fcst is 0.27; obs is 0.09; cf is 1.83; bc_fcst is 0.15
# date is 2019-04-24; fcst is 0.05; obs is 0.05; cf is 1.87; bc_fcst is 0.03
# date is 2019-04-25; fcst is 0.0; obs is 0.01; cf is 1.84; bc_fcst is 0.0
# date is 2019-04-26; fcst is 0.01; obs is 0.0; cf is 1.84; bc_fcst is 0.01
# date is 2019-04-27; fcst is 0.01; obs is 0.11; cf is 1.84; bc_fcst is 0.01
# date is 2019-04-28; fcst is 0.17; obs is 0.41; cf is 1.78; bc_fcst is 0.1
# date is 2019-04-29; fcst is 0.0; obs is 0.1; cf is 1.74; bc_fcst is 0.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-7810fec4e37a> in <module>()
#     122     plt.xlabel('Month', fontsize=20)
#     123     plt.ylabel('Precip Bias (")', fontsize=20)
# --> 124     plt.figtext(0.35, 0.85,name+" Raw 1.33-km WRF MAE = " + str(round(metrics.mean_absolute_error(df2[name+'4'],df2[name+'1']),3)), wrap=True,
#     125                 horizontalalignment='center', fontsize=16)
#     126     plt.figtext(0.35, 0.8,name+" Raw 1.33-km WRF MSE = " + str(round(metrics.mean_squared_error(df2[name+'4'],df2[name+'1']),3)), wrap=True,
#
# ~/anaconda3/envs/wrf-proj/lib/python3.6/site-packages/sklearn/metrics/regression.py in mean_absolute_error(y_true, y_pred, sample_weight, multioutput)
#     168     """
#     169     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 170         y_true, y_pred, multioutput)
#     171     output_errors = np.average(np.abs(y_pred - y_true),
#     172                                weights=sample_weight, axis=0)
#
# ~/anaconda3/envs/wrf-proj/lib/python3.6/site-packages/sklearn/metrics/regression.py in _check_reg_targets(y_true, y_pred, multioutput)
#      75     check_consistent_length(y_true, y_pred)
#      76     y_true = check_array(y_true, ensure_2d=False)
# ---> 77     y_pred = check_array(y_pred, ensure_2d=False)
#      78
#      79     if y_true.ndim == 1:
#
# ~/anaconda3/envs/wrf-proj/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     451                              % (array.ndim, estimator_name))
#     452         if force_all_finite:
# --> 453             _assert_all_finite(array)
#     454
#     455     shape_repr = _shape_repr(array.shape)
#
# ~/anaconda3/envs/wrf-proj/lib/python3.6/site-packages/sklearn/utils/validation.py in _assert_all_finite(X)
#      42             and not np.isfinite(X).all()):
#      43         raise ValueError("Input contains NaN, infinity"
# ---> 44                          " or a value too large for %r." % X.dtype)
#      45
#      46
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
